# %%
import pandas as pd

# %%
from pathlib import Path
txt = Path('day1-1.txt').read_text()

# %%
with open('day1-1.txt') as f:
    for line in f.readlines():
        print(line)

    # lines = f.readlines()
    # print(lines)
# Out:
# 6110
#
# 2550
#
# 6915
#
# 5699
#
# 4954
#
# 5093
#
# 3141
#
# 5939
#
# 4177
#
# 3544
#
# 5438
#
# 5391
#
# 3019
#
#
#
# 4691
#
# 6961
#
# 7515
#
# 4545
#
# 11145
#
# 8346
#
# 9225
#
#
#
# 9005
#
# 2121
#
# 4267
#
# 1808
#
# 3305
#
# 9701
#
# 1419
#
#
#
# 7178
#
# 4921
#
# 6687
#
# 1918
#
# 4856
#
# 4538
#
# 2786
#
# 5071
#
# 2689
#
# 1803
#
# 5763
#
#
#
# 12515
#
# 15649
#
# 17846
#
# 14135
#
#
#
# 3290
#
# 2875
#
# 1184
#
# 3166
#
# 3473
#
# 1683
#
# 2706
#
# 6297
#
# 2900
#
# 1684
#
# 4688
#
# 3074
#
#
#
# 3729
#
# 6105
#
# 7107
#
# 7027
#
# 5390
#
# 11429
#
# 8245
#
#
#
# 13381
#
# 12304
#
# 20944
#
#
#
# 18485
#
#
#
# 2108
#
# 5008
#
# 5779
#
# 3539
#
# 1633
#
# 3957
#
# 5475
#
# 1345
#
# 1526
#
# 1809
#
# 4355
#
# 3237
#
# 5006
#
# 2573
#
# 4353
#
#
#
# 1212
#
# 5163
#
# 3415
#
# 3937
#
# 2300
#
# 3454
#
# 4499
#
# 3970
#
# 5106
#
# 3476
#
# 5231
#
# 5849
#
# 5685
#
# 3991
#
#
#
# 4916
#
# 3093
#
# 4965
#
# 1996
#
# 3298
#
# 3331
#
# 3564
#
# 4052
#
# 2850
#
# 6755
#
# 5818
#
# ...

# %%
data
# Out:
# '6110\n2550\n6915\n5699\n4954\n5093\n3141\n5939\n4177\n3544\n5438\n5391\n3019\n\n4691\n6961\n7515\n4545\n11145\n8346\n9225\n\n9005\n2121\n4267\n1808\n3305\n9701\n1419\n\n7178\n4921\n6687\n1918\n4856\n4538\n2786\n5071\n2689\n1803\n5763\n\n12515\n15649\n17846\n14135\n\n3290\n2875\n1184\n3166\n3473\n1683\n2706\n6297\n2900\n1684\n4688\n3074\n\n3729\n6105\n7107\n7027\n5390\n11429\n8245\n\n13381\n12304\n20944\n\n18485\n\n2108\n5008\n5779\n3539\n1633\n3957\n5475\n1345\n1526\n1809\n4355\n3237\n5006\n2573\n4353\n\n1212\n5163\n3415\n3937\n2300\n3454\n4499\n3970\n5106\n3476\n5231\n5849\n5685\n3991\n\n4916\n3093\n4965\n1996\n3298\n3331\n3564\n4052\n2850\n6755\n5818\n5390\n1179\n\n4494\n1573\n5304\n5702\n2908\n3673\n1518\n2821\n3399\n3680\n1994\n1781\n3453\n5262\n2024\n\n2817\n4683\n3484\n4726\n5292\n5647\n1371\n3251\n4694\n2239\n5457\n3252\n2558\n3081\n4813\n\n6143\n6010\n4636\n1540\n2351\n1114\n1075\n1411\n2683\n2107\n1695\n1554\n6147\n1861\n\n10945\n8590\n\n17590\n15122\n2075\n\n66239\n\n4958\
# ...

# %%
myfile = open("day1-1.txt", "r")
data = ""
lines = myfile.readlines()

# %%
lines
# Out:
# ['6110\n',
#  '2550\n',
#  '6915\n',
#  '5699\n',
#  '4954\n',
#  '5093\n',
#  '3141\n',
#  '5939\n',
#  '4177\n',
#  '3544\n',
#  '5438\n',
#  '5391\n',
#  '3019\n',
#  '\n',
#  '4691\n',
#  '6961\n',
#  '7515\n',
#  '4545\n',
#  '11145\n',
#  '8346\n',
#  '9225\n',
#  '\n',
#  '9005\n',
#  '2121\n',
#  '4267\n',
#  '1808\n',
#  '3305\n',
#  '9701\n',
#  '1419\n',
#  '\n',
#  '7178\n',
#  '4921\n',
#  '6687\n',
#  '1918\n',
#  '4856\n',
#  '4538\n',
#  '2786\n',
#  '5071\n',
#  '2689\n',
#  '1803\n',
#  '5763\n',
#  '\n',
#  '12515\n',
#  '15649\n',
#  '17846\n',
#  '14135\n',
#  '\n',
#  '3290\n',
#  '2875\n',
#  '1184\n',
#  '3166\n',
#  '3473\n',
#  '1683\n',
#  '2706\n',
#  '6297\n',
#  '2900\n',
#  '1684\n',
#  '4688\n',
#  '3074\n',
#  '\n',
#  '3729\n',
#  '6105\n',
#  '7107\n',
#  '7027\n',
#  '5390\n',
#  '11429\n',
#  '8245\n',
#  '\n',
#  '13381\n',
#  '12304\n',
#  '20944\n',
#  '\n',
#  '18485\n',
#  '\n',
#  '2108\n',
#  '5008\n',
#  '5779\n',
#  '3539\n',
# ...
